# %% [markdown]
# <a href="https://colab.research.google.com/github/yosepprianto/Machine-Learning/blob/main/Soal1UTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
path_="/content/drive/My Drive/Machine_Learning/National Data.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#         Date  Active  Death  Recovery   Case
# 0   3/2/2020       2      0         0      2
# 1   3/3/2020       2      0         0      2
# 2   3/4/2020       2      0         0      2
# 3   3/5/2020       2      0         0      2
# 4   3/6/2020       4      0         0      4
# ..       ...     ...    ...       ...    ...
# 64  5/5/2020    9002    872      2197  12071
# 65  5/6/2020    9226    895      2317  12438
# 66  5/7/2020    9465    930      2381  12776
# 67  5/8/2020    9675    943      2494  13112
# 68  5/9/2020   10079    959      2607  13645
#
# [69 rows x 5 columns]

# %%
dataset.head()
# Out:
#        Date  Active  Death  Recovery  Case
# 0  3/2/2020       2      0         0     2
# 1  3/3/2020       2      0         0     2
# 2  3/4/2020       2      0         0     2
# 3  3/5/2020       2      0         0     2
# 4  3/6/2020       4      0         0     4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(dataset['Date'],dataset['Active'])

# %%
plt.scatter(dataset['Date'],dataset['Death'])

# %%
plt.scatter(dataset['Date'],dataset['Recovery'])

# %%
plt.scatter(dataset['Date'],dataset['Case'])

# %%
x=dataset[['Date','Active','Death','Recovery']]
y=dataset['Case']

# %%
x
# Out:
#         Date  Active  Death  Recovery
# 0   3/2/2020       2      0         0
# 1   3/3/2020       2      0         0
# 2   3/4/2020       2      0         0
# 3   3/5/2020       2      0         0
# 4   3/6/2020       4      0         0
# ..       ...     ...    ...       ...
# 64  5/5/2020    9002    872      2197
# 65  5/6/2020    9226    895      2317
# 66  5/7/2020    9465    930      2381
# 67  5/8/2020    9675    943      2494
# 68  5/9/2020   10079    959      2607
#
# [69 rows x 4 columns]

# %%
y
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         4
#       ...
# 64    12071
# 65    12438
# 66    12776
# 67    13112
# 68    13645
# Name: Case, Length: 69, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
len(x_train)
# Out:
# 48

# %%
len(x_test)
# Out:
# 21

# %%
x_train
# Out:
#          Date  Active  Death  Recovery
# 28  3/30/2020    1217    122        75
# 42  4/13/2020    3778    399       380
# 1    3/3/2020       2      0         0
# 55  4/26/2020    7032    743      1107
# 11  3/13/2020      63      4         2
# 20  3/22/2020     437     48        29
# 61   5/2/2020    8347    831      1665
# 0    3/2/2020       2      0         0
# 4    3/6/2020       4      0         0
# 40  4/11/2020    3229    327       286
# 25  3/27/2020     913     87        46
# 66   5/7/2020    9465    930      2381
# 63   5/4/2020    8769    864      1954
# 7    3/9/2020      19      0         0
# 54  4/25/2020    6845    720      1042
# 68   5/9/2020   10079    959      2607
# 62   5/3/2020    8471    845      1876
# 59  4/30/2020    7804    792      1522
# 24  3/26/2020     780     78        35
# 13  3/15/2020     104      5         8
# 53  4/24/2020    6520    689      1002
# 15  3/17/2020     158      5         9
# 45  4/16/2020    4472    496       548
# ...

# %%
x_test
# Out:
#          Date  Active  Death  Recovery
# 32   4/3/2020    1671    181       134
# 2    3/4/2020       2      0         0
# 12  3/14/2020      83      5         8
# 64   5/5/2020    9002    872      2197
# 8   3/10/2020      25      0         2
# 38   4/9/2020    2761    280       252
# 19  3/21/2020     392     38        20
# 36   4/7/2020    2313    221       204
# 49  4/20/2020    5423    590       747
# 56  4/27/2020    7180    765      1151
# 17  3/19/2020     269     25        15
# 18  3/20/2020     320     32        17
# 5    3/7/2020       4      0         0
# 29  3/31/2020    1311    136        81
# 3    3/5/2020       2      0         0
# 23  3/25/2020     701     58        31
# 44  4/15/2020    4221    469       446
# 39  4/10/2020    2924    306       282
# 43  4/14/2020    3954    459       426
# 31   4/2/2020    1508    170       112
# 57  4/28/2020    7484    773      1254

# %%
y_test
# Out:
# 32     1986
# 2         2
# 12       96
# 64    12071
# 8        27
# 38     3293
# 19      450
# 36     2738
# 49     6760
# 56     9096
# 17      309
# 18      369
# 5         4
# 29     1528
# 3         2
# 23      790
# 44     5136
# 39     3512
# 43     4839
# 31     1790
# 57     9511
# Name: Case, dtype: int64

# %%
y_train
# Out:
# 28     1414
# 42     4557
# 1         2
# 55     8882
# 11       69
# 20      514
# 61    10843
# 0         2
# 4         4
# 40     3842
# 25     1046
# 66    12776
# 63    11587
# 7        19
# 54     8607
# 68    13645
# 62    11192
# 59    10118
# 24      893
# 13      117
# 53     8211
# 15      172
# 45     5516
# 34     2273
# 67    13112
# 26     1155
# 60    10551
# 30     1677
# 58     9771
# 52     7775
# 48     6575
# 65    12438
# 50     7135
# 27     1285
# 22      686
# 33     2092
# 37     2956
# 41     4241
# 6         6
# 14      134
# 35     2491
# 10       34
# 9        34
# 21      579
# 51     7418
# 46     5923
# 16      227
# 47     6248
# Name: Case, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 55

# %%
len(x_test)
# Out:
# 14

# %%
x_train
# Out:
#          Date  Active  Death  Recovery
# 43  4/14/2020    3954    459       426
# 11  3/13/2020      63      4         2
# 58  4/29/2020    7596    784      1391
# 25  3/27/2020     913     87        46
# 42  4/13/2020    3778    399       380
# 52  4/23/2020    6168    647       960
# 36   4/7/2020    2313    221       204
# 54  4/25/2020    6845    720      1042
# 8   3/10/2020      25      0         2
# 3    3/5/2020       2      0         0
# 64   5/5/2020    9002    872      2197
# 48  4/19/2020    5307    582       686
# 6    3/8/2020       6      0         0
# 46  4/17/2020    4796    520       607
# 50  4/21/2020    5677    616       842
# 1    3/3/2020       2      0         0
# 32   4/3/2020    1671    181       134
# 33   4/4/2020    1751    191       150
# 31   4/2/2020    1508    170       112
# 65   5/6/2020    9226    895      2317
# 59  4/30/2020    7804    792      1522
# 23  3/25/2020     701     58        31
# 66   5/7/2020    9465    930      2381
# ...

# %%
x_test
# Out:
#          Date  Active  Death  Recovery
# 5    3/7/2020       4      0         0
# 56  4/27/2020    7180    765      1151
# 68   5/9/2020   10079    959      2607
# 34   4/5/2020    1911    198       164
# 51  4/22/2020    5870    635       913
# 61   5/2/2020    8347    831      1665
# 67   5/8/2020    9675    943      2494
# 27  3/29/2020    1107    114        64
# 53  4/24/2020    6520    689      1002
# 37   4/8/2020    2494    240       222
# 16  3/18/2020     197     19        11
# 15  3/17/2020     158      5         9
# 4    3/6/2020       4      0         0
# 21  3/23/2020     500     49        30

# %%
y_train
# Out:
# 43     4839
# 11       69
# 58     9771
# 25     1046
# 42     4557
# 52     7775
# 36     2738
# 54     8607
# 8        27
# 3         2
# 64    12071
# 48     6575
# 6         6
# 46     5923
# 50     7135
# 1         2
# 32     1986
# 33     2092
# 31     1790
# 65    12438
# 59    10118
# 23      790
# 66    12776
# 18      369
# 49     6760
# 22      686
# 17      309
# 7        19
# 55     8882
# 62    11192
# 57     9511
# 14      134
# 24      893
# 28     1414
# 30     1677
# 45     5516
# 39     3512
# 2         2
# 35     2491
# 26     1155
# 12       96
# 47     6248
# 20      514
# 13      117
# 19      450
# 40     3842
# 29     1528
# 60    10551
# 41     4241
# 38     3293
# 63    11587
# 10       34
# 44     5136
# 9        34
# 0         2
# Name: Case, dtype: int64

# %%
y_test
# Out:
# 5         4
# 56     9096
# 68    13645
# 34     2273
# 51     7418
# 61    10843
# 67    13112
# 27     1285
# 53     8211
# 37     2956
# 16      227
# 15      172
# 4         4
# 21      579
# Name: Case, dtype: int64
